# %% [markdown]
# # Face Shield — benchmark stub
#
# Use this notebook to batch-process images, log PSNR, and compare probe outputs. Add paths to `backend/` on `sys.path` before importing `services`.

# %%
# import sys
# sys.path.insert(0, "../backend")
# from services.noise_composer import compose, ShieldParams
# from utils.image_utils import bytes_to_bgr, bgr_to_png_bytes
pass
